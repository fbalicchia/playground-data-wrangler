# %% [markdown]
# ## Environment creation:

# %% [markdown]
# ```sh
# mamba create -n ibis-substrait-duckdb python=3.10 ibis-duckdb ibis-substrait python-duckdb duckdb-engine=0.1.10 jupyter
# conda activate ibis-substrait-duckdb
#
# # install latest dev version of duckdb
# python -m pip install -U duckdb==0.4.0
# ```

# %%
import ibis
import ibis.expr.datatypes as dt
from datetime import date
from pathlib import Path

# %%
print(ibis.__version__)
# Out:
# 3.0.2

# %% [markdown]
# `ibis-substrait` compiler

# %%
import ibis_substrait
from ibis_substrait.compiler.core import SubstraitCompiler

print(ibis_substrait.__version__)
# Out:
# 2.9.2

# %% [markdown]
# `duckdb` Python wrapper

# %%
import duckdb

print(duckdb.__version__)
# Out:
# 0.4.0

# %% [markdown]
# ### Create `TPC-H` sample data with scale factor of 0.1 for demo

# %%
Path("tpch.ddb").unlink(missing_ok=True)

# %%
con = duckdb.connect("tpch.ddb")

# %%
con.execute("CALL dbgen(sf=0.1)")

# %% [markdown]
# ### Install and load `duckdb` `substrait` extension

# %%
con.execute("install substrait")

# %%
con.execute("load substrait")

# %% [markdown]
# Load `ibis` and create unbound `TPC-H` tables

# %%
lineitem = ibis.table(
    [
        ("l_orderkey", dt.int64),
        ("l_partkey", dt.int64),
        ("l_suppkey", dt.int64),
        ("l_linenumber", dt.int64),
        ("l_quantity", dt.Decimal(15, 2)),
        ("l_extendedprice", dt.Decimal(15, 2)),
        ("l_discount", dt.Decimal(15, 2)),
        ("l_tax", dt.Decimal(15, 2)),
        ("l_returnflag", dt.string),
        ("l_linestatus", dt.string),
        ("l_shipdate", dt.date),
        ("l_commitdate", dt.date),
        ("l_receiptdate", dt.date),
        ("l_shipinstruct", dt.string),
        ("l_shipmode", dt.string),
        ("l_comment", dt.string),
    ],
    name="lineitem",
)

# %%
lineitem
# Out:
# UnboundTable: lineitem
#   l_orderkey      int64
#   l_partkey       int64
#   l_suppkey       int64
#   l_linenumber    int64
#   l_quantity      decimal(prec=15, scale=2)
#   l_extendedprice decimal(prec=15, scale=2)
#   l_discount      decimal(prec=15, scale=2)
#   l_tax           decimal(prec=15, scale=2)
#   l_returnflag    string
#   l_linestatus    string
#   l_shipdate      date
#   l_commitdate    date
#   l_receiptdate   date
#   l_shipinstruct  string
#   l_shipmode      string
#   l_comment       string

# %% [markdown]
# TPC-H Query 1 in Ibis

# %%
tpc_h1_expr = (
    lineitem.filter(lambda t: t.l_shipdate <= date(year=1998, month=9, day=2))
    .group_by(["l_returnflag", "l_linestatus"])
    .aggregate(
        sum_qty=lambda t: t.l_quantity.sum(),
        sum_base_price=lambda t: t.l_extendedprice.sum(),
        sum_disc_price=lambda t: (t.l_extendedprice * (1 - t.l_discount)).sum(),
        sum_charge=lambda t: (
            t.l_extendedprice * (1 - t.l_discount) * (1 + t.l_tax)
        ).sum(),
        avg_qty=lambda t: t.l_quantity.mean(),
        avg_price=lambda t: t.l_extendedprice.mean(),
        avg_disc=lambda t: t.l_discount.mean(),
        count_order=lambda t: t.count(),
    )
    .sort_by(["l_returnflag", "l_linestatus"])
)

# %%
tpc_h1_expr
# Out:
# r0 := UnboundTable: lineitem
#   l_orderkey      int64
#   l_partkey       int64
#   l_suppkey       int64
#   l_linenumber    int64
#   l_quantity      decimal(prec=15, scale=2)
#   l_extendedprice decimal(prec=15, scale=2)
#   l_discount      decimal(prec=15, scale=2)
#   l_tax           decimal(prec=15, scale=2)
#   l_returnflag    string
#   l_linestatus    string
#   l_shipdate      date
#   l_commitdate    date
#   l_receiptdate   date
#   l_shipinstruct  string
#   l_shipmode      string
#   l_comment       string
#
# r1 := Aggregation[r0]
#   metrics:
#     sum_qty:        Sum(r0.l_quantity)
#     sum_base_price: Sum(r0.l_extendedprice)
#     sum_disc_price: Sum(r0.l_extendedprice * 1 - r0.l_discount)
#     sum_charge:     Sum(r0.l_extendedprice * 1 - r0.l_discount * r0.l_tax + 1)
#     avg_qty:        Mean(r0.l_quantity)
#     avg_price:      Mean(r0.l_extendedprice)
#     avg_disc:       Mean(r0.l_discount)
#     count_order:    Count(lineitem)
#   by:
#     l_returnflag: r0.l_returnflag
#     l_linestatus: r0.l_linestatus
#   predicates:
#     r0.l_shipdate <= datetime.date(1998, 9, 2)
#
# Selection[r1]
#   sort_keys:
#      asc|r1.l_returnflag
#      asc|r1.l_linestatus

# %% [markdown]
# Import `ibis-subtrait` compiler to serialize `ibis` expression to `substrait`

# %%
compiler = SubstraitCompiler()

# %%
tpch_proto_bytes = compiler.compile(tpc_h1_expr)

# %%
tpch_proto_bytes
# Out:
# extension_uris {
#   extension_uri_anchor: 1
# }
# extensions {
#   extension_function {
#     extension_uri_reference: 1
#     function_anchor: 1
#     name: "lte"
#   }
# }
# extensions {
#   extension_function {
#     extension_uri_reference: 1
#     function_anchor: 2
#     name: "sum"
#   }
# }
# extensions {
#   extension_function {
#     extension_uri_reference: 1
#     function_anchor: 3
#     name: "multiply"
#   }
# }
# extensions {
#   extension_function {
#     extension_uri_reference: 1
#     function_anchor: 4
#     name: "subtract"
#   }
# }
# extensions {
#   extension_function {
#     extension_uri_reference: 1
#     function_anchor: 5
#     name: "add"
#   }
# }
# extensions {
#   extension_function {
#     extension_uri_reference: 1
#     function_anchor: 6
#     name: "mean"
#   }
# }
# extensions {
#   extension_function {
#     extension_uri_reference: 1
#     function_anchor: 7
#     name: "count"
#   }
# }
# relations {
#   root {
#     input {
#       sort {
#         input {
#           aggregate {
#             input {
#               filter {
#                 input {
#                   read {
#                     base_schema {
#                       names: "l_orderkey"
#                       names: "l_partkey"
#                       names: "l_suppkey"
#                       names: "l_linenumber"
#                       names: "l_quantity"
#                       names: "l_extendedprice"
#                       names: "l_discount"
#                       names: "l_tax"
#                       names: "l_returnflag"
#                       names: "l_linestatus"
#                       names: "l_shipdate"
#                       names: "l_commitdate"
#                       names: "l_receiptdate"
#                       names: "l_shipinstruct"
#                       names: "l_shipmode"
#                       names: "l_comment"
#                       struct {
#                         types {
#                           i64 {
#                             nullability: NULLABILITY_NULLABLE
#                           }
#                         }
#                         types {
#                           i64 {
#                             nullability: NULLABILITY_NULLABLE
#                           }
#                         }
#                         types {
#                           i64 {
#                             nullability: NULLABILITY_NULLABLE
#                           }
#                         }
#                         types {
#                           i64 {
#                             nullability: NULLABILITY_NULLABLE
#                           }
#                         }
#                         types {
#                           decimal {
#                             scale: 2
#                             precision: 15
#                             nullability: NULLABILITY_NULLABLE
#                           }
#                         }
#                         types {
#                           decimal {
#                             scale: 2
#                             precision: 15
#                             nullability: NULLABILITY_NULLABLE
#                           }
#                         }
#                         types {
#                           decimal {
#                             scale: 2
#                             precision: 15
#                             nullability: NULLABILITY_NULLABLE
#                           }
#                         }
#                         types {
#                           decimal {
#                             scale: 2
#                             precision: 15
#                             nullability: NULLABILITY_NULLABLE
#                           }
#                         }
#                         types {
#                           string {
#                             nullability: NULLABILITY_NULLABLE
#                           }
#                         }
#                         types {
#                           string {
#                             nullability: NULLABILITY_NULLABLE
#                           }
#                         }
#                         types {
#                           date {
#                             nullability: NULLABILITY_NULLABLE
#                           }
#                         }
#                         types {
#                           date {
#                             nullability: NULLABILITY_NULLABLE
#                           }
#                         }
#                         types {
#                           date {
#                             nullability: NULLABILITY_NULLABLE
#                           }
#                         }
#                         types {
#                           string {
#                             nullability: NULLABILITY_NULLABLE
#                           }
#                         }
#                         types {
#                           string {
#                             nullability: NULLABILITY_NULLABLE
#                           }
#                         }
#                         types {
#                           string {
#                             nullability: NULLABILITY_NULLABLE
#                           }
#                         }
#                         nullability: NULLABILITY_REQUIRED
#                       }
#                     }
#                     named_table {
#                       names: "lineitem"
#                     }
#                   }
#                 }
#                 condition {
#                   scalar_function {
#                     function_reference: 1
#                     args {
#                       selection {
#                         direct_reference {
#                           struct_field {
#                             field: 10
#                           }
#                         }
#                         root_reference {
#                         }
#                       }
#                     }
#                     args {
#                       literal {
#                         date: 10471
#                         nullable: true
#                       }
#                     }
#                     output_type {
#                       bool {
#                         nullability: NULLABILITY_NULLABLE
#                       }
#                     }
#                   }
#                 }
#               }
#             }
#             groupings {
#               grouping_expressions {
#                 selection {
#                   direct_reference {
#                     struct_field {
#                       field: 8
#                     }
#                   }
#                   root_reference {
#                   }
#                 }
#               }
#             }
#             groupings {
#               grouping_expressions {
#                 selection {
#                   direct_reference {
#                     struct_field {
#                       field: 9
#                     }
#                   }
#                   root_reference {
#                   }
#                 }
#               }
#             }
#             measures {
#               measure {
#                 function_reference: 2
#                 args {
#                   selection {
#                     direct_reference {
#                       struct_field {
#                         field: 4
#                       }
#                     }
#                     root_reference {
#                     }
#                   }
#                 }
#                 phase: AGGREGATION_PHASE_INITIAL_TO_RESULT
#                 output_type {
#                   decimal {
#                     nullability: NULLABILITY_NULLABLE
#                   }
#                 }
#               }
#             }
#             measures {
#               measure {
#                 function_reference: 2
#                 args {
#                   selection {
#                     direct_reference {
#                       struct_field {
#                         field: 5
#                       }
#                     }
#                     root_reference {
#                     }
#                   }
#                 }
#                 phase: AGGREGATION_PHASE_INITIAL_TO_RESULT
#                 output_type {
#                   decimal {
#                     nullability: NULLABILITY_NULLABLE
#                   }
#                 }
#               }
#             }
#             measures {
#               measure {
#                 function_reference: 2
#                 args {
#                   scalar_function {
#                     function_reference: 3
#                     args {
#                       selection {
#                         direct_reference {
#                           struct_field {
#                             field: 5
#                           }
#                         }
#                         root_reference {
#                         }
#                       }
#                     }
#                     args {
#                       scalar_function {
#                         function_reference: 4
#                         args {
#                           literal {
#                             i8: 1
#                             nullable: true
#                           }
#                         }
#                         args {
#                           selection {
#                             direct_reference {
#                               struct_field {
#                                 field: 6
#                               }
#                             }
#                             root_reference {
#                             }
#                           }
#                         }
#                         output_type {
#                           decimal {
#                             scale: 2
#                             precision: 15
#                             nullability: NULLABILITY_NULLABLE
#                           }
#                         }
#                       }
#                     }
#                     output_type {
#                       decimal {
#                         scale: 2
#                         precision: 15
#                         nullability: NULLABILITY_NULLABLE
#                       }
#                     }
#                   }
#                 }
#                 phase: AGGREGATION_PHASE_INITIAL_TO_RESULT
#                 output_type {
#                   decimal {
#                     nullability: NULLABILITY_NULLABLE
#                   }
#                 }
#               }
#             }
#             measures {
#               measure {
#                 function_reference: 2
#                 args {
#                   scalar_function {
#                     function_reference: 3
#                     args {
#                       scalar_function {
#                         function_reference: 3
#                         args {
#                           selection {
#                             direct_reference {
#                               struct_field {
#                                 field: 5
#                               }
#                             }
#                             root_reference {
#                             }
#                           }
#                         }
#                         args {
#                           scalar_function {
#                             function_reference: 4
#                             args {
#                               literal {
#                                 i8: 1
#                                 nullable: true
#                               }
#                             }
#                             args {
#                               selection {
#                                 direct_reference {
#                                   struct_field {
#                                     field: 6
#                                   }
#                                 }
#                                 root_reference {
#                                 }
#                               }
#                             }
#                             output_type {
#                               decimal {
#                                 scale: 2
#                                 precision: 15
#                                 nullability: NULLABILITY_NULLABLE
#                               }
#                             }
#                           }
#                         }
#                         output_type {
#                           decimal {
#                             scale: 2
#                             precision: 15
#                             nullability: NULLABILITY_NULLABLE
#                           }
#                         }
#                       }
#                     }
#                     args {
#                       scalar_function {
#                         function_reference: 5
#                         args {
#                           selection {
#                             direct_reference {
#                               struct_field {
#                                 field: 7
#                               }
#                             }
#                             root_reference {
#                             }
#                           }
#                         }
#                         args {
#                           literal {
#                             i8: 1
#                             nullable: true
#                           }
#                         }
#                         output_type {
#                           decimal {
#                             scale: 2
#                             precision: 15
#                             nullability: NULLABILITY_NULLABLE
#                           }
#                         }
#                       }
#                     }
#                     output_type {
#                       decimal {
#                         scale: 2
#                         precision: 15
#                         nullability: NULLABILITY_NULLABLE
#                       }
#                     }
#                   }
#                 }
#                 phase: AGGREGATION_PHASE_INITIAL_TO_RESULT
#                 output_type {
#                   decimal {
#                     nullability: NULLABILITY_NULLABLE
#                   }
#                 }
#               }
#             }
#             measures {
#               measure {
#                 function_reference: 6
#                 args {
#                   selection {
#                     direct_reference {
#                       struct_field {
#                         field: 4
#                       }
#                     }
#                     root_reference {
#                     }
#                   }
#                 }
#                 phase: AGGREGATION_PHASE_INITIAL_TO_RESULT
#                 output_type {
#                   decimal {
#                     scale: 2
#                     precision: 15
#                     nullability: NULLABILITY_NULLABLE
#                   }
#                 }
#               }
#             }
#             measures {
#               measure {
#                 function_reference: 6
#                 args {
#                   selection {
#                     direct_reference {
#                       struct_field {
#                         field: 5
#                       }
#                     }
#                     root_reference {
#                     }
#                   }
#                 }
#                 phase: AGGREGATION_PHASE_INITIAL_TO_RESULT
#                 output_type {
#                   decimal {
#                     scale: 2
#                     precision: 15
#                     nullability: NULLABILITY_NULLABLE
#                   }
#                 }
#               }
#             }
#             measures {
#               measure {
#                 function_reference: 6
#                 args {
#                   selection {
#                     direct_reference {
#                       struct_field {
#                         field: 6
#                       }
#                     }
#                     root_reference {
#                     }
#                   }
#                 }
#                 phase: AGGREGATION_PHASE_INITIAL_TO_RESULT
#                 output_type {
#                   decimal {
#                     scale: 2
#                     precision: 15
#                     nullability: NULLABILITY_NULLABLE
#                   }
#                 }
#               }
#             }
#             measures {
#               measure {
#                 function_reference: 7
#                 phase: AGGREGATION_PHASE_INITIAL_TO_RESULT
#                 output_type {
#                   i64 {
#                     nullability: NULLABILITY_NULLABLE
#                   }
#                 }
#               }
#             }
#           }
#         }
#         sorts {
#           expr {
#             selection {
#               direct_reference {
#                 struct_field {
#                 }
#               }
#               root_reference {
#               }
#             }
#           }
#           direction: SORT_DIRECTION_ASC_NULLS_FIRST
#         }
#         sorts {
#           expr {
#             selection {
#               direct_reference {
#                 struct_field {
#                   field: 1
#                 }
#               }
#               root_reference {
#               }
#             }
#           }
#           direction: SORT_DIRECTION_ASC_NULLS_FIRST
#         }
#       }
#     }
#     names: "l_returnflag"
#     names: "l_linestatus"
#     names: "sum_qty"
#     names: "sum_base_price"
#     names: "sum_disc_price"
#     names: "sum_charge"
#     names: "avg_qty"
#     names: "avg_price"
#     names: "avg_disc"
#     names: "count_order"
#   }
# }

# %% [markdown]
# Now let's return to our `duckdb` connection

# %%
con

# %%
results_substrait = con.from_substrait(tpch_proto_bytes.SerializeToString())

# %%
results_substrait_df = results_substrait.to_df()
results_substrait_df
# Out:
#   l_returnflag l_linestatus    sum_qty  sum_base_price  sum_disc_price  \
# 0            A            F  3774200.0    5.320754e+09    5.054096e+09
# 1            N            F    95257.0    1.337378e+08    1.271324e+08
# 2            N            O  7459297.0    1.051227e+10    9.986238e+09
# 3            R            F  3785523.0    5.337951e+09    5.071819e+09
#
#      sum_charge    avg_qty     avg_price  avg_disc  count_order
# 0  5.256751e+09  25.537587  36002.123829  0.050145       147790
# 1  1.322863e+08  25.300664  35521.326916  0.049394         3765
# 2  1.038558e+10  25.545538  36000.924688  0.050096       292000
# 3  5.274406e+09  25.525944  35994.029214  0.049989       148301

# %% [markdown]
# Now delete the `duckdb` con and let's re-run the query using the `ibis.duckdb` backend to compare results

# %%
del con

# %% [markdown]
# Create `ibis-duckdb` connection

# %%
con = ibis.duckdb.connect("tpch.ddb")

# %%
results_ibis_duckdb = con.execute(tpc_h1_expr)
# Out:
# /home/gil/mambaforge/envs/ibis-substrait-duckdb/lib/python3.10/site-packages/ibis/backends/base/sql/__init__.py:95: SAWarning: Dialect duckdb+psycopg2 does *not* support Decimal objects natively, and SQLAlchemy must convert from floating point - rounding errors and other issues may occur. Please consider storing Decimal numbers as strings or integers on this platform for lossless storage.
#   cursor = self.con.execute(query)  # type: ignore

# %%
results_ibis_duckdb
# Out:
#   l_returnflag l_linestatus    sum_qty sum_base_price     sum_disc_price  \
# 0            A            F  3774200.0  5320753880.69    5054096266.6828
# 1            N            F    95257.0   133737795.84     127132372.6512
# 2            N            O  7459297.0  10512270008.9  9986238338.384701
# 3            R            F  3785523.0  5337950526.47     5071818532.942
#
#            sum_charge    avg_qty     avg_price  avg_disc  count_order
# 0   5256751331.449234  25.537587  36002.123829  0.050145       147790
# 1    132286291.229445  25.300664  35521.326916  0.049394         3765
# 2  10385578376.585468  25.545538  36000.924688  0.050096       292000
# 3   5274405503.049367  25.525944  35994.029214  0.049989       148301

# %% [markdown]
# Minor annoyance that the `ibis` results come back as `object` type and `duckdb` comes back as `float64` -- quick `astype` cast before value comparison

# %%
results_ibis_duckdb = results_ibis_duckdb.astype(
    {
        "sum_qty": "float64",
        "sum_base_price": "float64",
        "sum_disc_price": "float64",
        "sum_charge": "float64",
        "avg_qty": "float64",
        "avg_price": "float64",
        "avg_disc": "float64",
    }
)

# %%
results_ibis_duckdb.equals(results_substrait_df)
# Out:
# True
